# %%
line([(0,0),(1,2),(2,0)]) # ou line([[0,0],[1,2],[2,0]])
# Out:
# Graphics object consisting of 1 graphics primitive

# %%
x=var('x') #déclarationdelavariablesymbolique
f(x)=sin(10*x)/(1+x^2)
G1=plot(f,(-3,3)) #Constructiondugraphique
G1.show() #affichagedugraphique
# Out:
# Graphics object consisting of 1 graphics primitive
